# %% [markdown]
# # Clase 10
#
# El objetivo de esta clase es tener un acercamiento con el procesamiento de lenguaje natural, donde nos centraremos en la cantidad de Bag of Words para una cantidad grande de documentos.
#
# * Tokens
#
# * Documentos
#
# * Bag of Words
#
# Considerando los datos de la red social Twitter (X) [fuente de datos](https://www.kaggle.com/datasets/vstepanenko/disaster-tweets), se tiene una cantidad de tuits asociados a accidentes, incendios forestales y covid-19.

# %%
from google.colab import drive # conectar con datos de drive
drive.mount('/content/gdrive')
import pandas as pd # manejo de data frame
import numpy as np # manejos matriciales
import nltk # paquete 1 de lenguaje natural
import re # paquete 2 de lenguaje natural
from nltk.corpus import stopwords # conjunto de stopwords
from nltk.tokenize import TweetTokenizer # tokenizador de tweet
from nltk.stem import PorterStemmer # hacer steming palabras
from nltk.stem import LancasterStemmer # hacer steming palabras
from nltk.stem import WordNetLemmatizer # extraer el lema de una palabra
import matplotlib.pyplot as plt
from wordcloud import WordCloud  # graficos de palabras

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('words')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# A continuación, tenemos un conjunto de tuits, crearemos tokens e identificaremos la cantidad de bag of words.

# %%
datos_x=pd.read_csv("/content/gdrive/MyDrive/Aprendizaje no supervisado/Base de datos/tweets.csv")
datos_x["text"]
# Out:
# 0        Communal violence in Bhainsa, Telangana. "Ston...
# 1        Telangana: Section 144 has been imposed in Bha...
# 2        Arsonist sets cars ablaze at dealership https:...
# 3        Arsonist sets cars ablaze at dealership https:...
# 4        "Lord Jesus, your love brings freedom and pard...
#                                ...
# 11365    Media should have warned us well in advance. T...
# 11366    i feel directly attacked 💀 i consider moonbin ...
# 11367    i feel directly attacked 💀 i consider moonbin ...
# 11368    ok who remember "outcast" nd the "dora" au?? T...
# 11369       Jake Corway wrecked while running 14th at IRP.
# Name: text, Length: 11370, dtype: object

# %% [markdown]
# # Documento
#
# Para este caso vamos a considerar un solo documento.

# %%
texto = datos_x["text"].loc[0]
texto
# Out:
# 'Communal violence in Bhainsa, Telangana. "Stones were pelted on Muslims\' houses and some houses and vehicles were set ablaze…'

# %% [markdown]
# Inicialmente se pasa el texto a minúscula o mayúscula, en la práctica se pasa a minúscula.

# %%
texto = texto.lower()
texto
# Out:
# 'communal violence in bhainsa, telangana. "stones were pelted on muslims\' houses and some houses and vehicles were set ablaze…'

# %%
texto.split(".") # con split podemos determinar un caracter para separar las plabras
# Out:
# ['communal violence in bhainsa, telangana',
#  ' "stones were pelted on muslims\' houses and some houses and vehicles were set ablaze…']

# %%
tokens = texto.split( ) # separa por espacios, \n, multiples espacios.
print( "Tokens: ", tokens )
print("Cantidad tokens:",len(tokens )) # len cantidad de elementos en la lista
# Out:
# Tokens:  ['communal', 'violence', 'in', 'bhainsa,', 'telangana.', '"stones', 'were', 'pelted', 'on', "muslims'", 'houses', 'and', 'some', 'houses', 'and', 'vehicles', 'were', 'set', 'ablaze…']
# Cantidad tokens: 19

# %% [markdown]
# Ahora para definir el Bag of Words es con la cantidad de tokens únicos, utilizando la funcón set, podemos obtener los valores únicos de una lista.

# %%
print( "Bag of words: ", set(tokens)  )
print("Cantidad Bag of words: ",len(set(tokens) ))
# Out:
# Bag of words:  {'ablaze…', 'some', '"stones', 'and', 'set', 'houses', 'communal', 'vehicles', 'on', 'were', 'pelted', 'in', 'violence', "muslims'", 'telangana.', 'bhainsa,'}
# Cantidad Bag of words:  16

# %% [markdown]
# Se observan problemas como las comillas y signos de puntuación, pero principalmente los stop words, in, on, and puede que no den mucha información.
#
# Con  la librería nlk, existe una lista de stopword que ya se consideraron como stop words de manera general, sin embargo, esta se puede modificar a conveniencia.

# %% [markdown]
# # Stop Words
#
# Con la librería de nltk, se tiene una lista de stop words predeterminadas, que se han considerado stop word de manera genérica para diferentes idiomas, esto no significa que dicha lista no se pueda modificar, ya sea quitando o añadiendo nuevas palabras que consideremos un stop word.

# %%
stop_words_nltk_en =list(set(stopwords.words('english')))
print(stop_words_nltk_en)
len(stop_words_nltk_en)
# Out:
# ['does', 'a', 'll', 'up', 'don', 'not', 'myself', 'ourselves', 'his', 'above', 'mustn', 'she', "should've", "that'll", 'their', 'mightn', "hasn't", 'won', 'from', 'who', 'few', 'by', "you've", 'own', 'very', 'same', 'with', 'whom', 'how', 'this', 'do', 'isn', 'through', 'that', "shan't", 'between', 'shouldn', 'he', 'theirs', 'didn', 'only', 'until', 'my', "you're", 'all', 'those', 'just', 'below', "haven't", 'are', 'further', 'needn', 'is', 'yourselves', 'an', 'doesn', 'her', 'had', 'as', 'y', 'off', 'i', 'themselves', 'during', 'once', 'haven', 'couldn', 'hadn', "you'll", 'ain', 'before', 'when', 'for', "couldn't", 'the', 'wasn', 'him', "mustn't", 'out', 'because', 'after', 'so', 'each', 'them', 'more', 'can', 'if', 'it', 'too', 'itself', 'which', 'nor', 'both', 'yourself', 'should', "wasn't", "weren't", 'you', 'against', 'will', 'they', 'having', 'hers', "hadn't", 'but', 'was', "wouldn't", 've', "needn't", 'these', 'its', 'where', 'wouldn', 'your', 'into', 'd', 'being', 'herself', 'some', 'we', 'have', 'no', 'am', 'most', 'why', 'has', 'aren', "it's", 't', 'yours', 'over', 'again', 'were', 'than', "mightn't", 'our', "doesn't", "shouldn't", 'any', "isn't", 'and', "won't", 'm', 'such', 'what', 'or', 'been', 'now', 's', 'o', 'ma', 'down', 'under', 'of', 'himself', 'on', "she's", 'ours', "you'd", "aren't", "didn't", 'other', 'me', 'hasn', 'in', 'be', 'doing', 'here', 'to', 'did', 'then', 're', 'weren', "don't", 'about', 'shan', 'there', 'at', 'while']
# 179

# %%
stop_words_nltk_es =list(set(stopwords.words('spanish')))
print(stop_words_nltk_es)
len(stop_words_nltk_es)
# Out:
# ['tuviese', 'habríais', 'somos', 'otra', 'habría', 'hubiésemos', 'tuvo', 'tuyas', 'durante', 'donde', 'otras', 'vosotras', 'tenía', 'habrá', 'estaré', 'he', 'estarían', 'desde', 'habríamos', 'estuviéramos', 'con', 'tengo', 'tuvieses', 'fueran', 'esté', 'serán', 'habré', 'pero', 'tendríamos', 'les', 'mías', 'estabais', 'estarán', 'tuvieseis', 'estado', 'es', 'tenidos', 'estuvierais', 'teniendo', 'del', 'tuviesen', 'nuestros', 'que', 'nuestra', 'seas', 'ellos', 'tuvieras', 'eso', 'suya', 'tened', 'estando', 'hubisteis', 'tenían', 'habiendo', 'estuvieseis', 'habido', 'una', 'tenga', 'habrías', 'tendrías', 'hubieseis', 'habíamos', 'habían', 'hasta', 'estuvimos', 'también', 'a', 'tanto', 'nosotras', 'estuvieras', 'estos', 'el', 'habrás', 'hube', 'otro', 'quienes', 'estuvieran', 'sentidas', 'estáis', 'hubieron', 'sean', 'tus', 'suyos', 'será', 'hubiste', 'porque', 'fuerais', 'muy', 'un', 'estarás', 'en', 'eran', 'y', 'algunos', 'estuvo', 'habida', 'estén', 'estés', 'tenidas', 'tendrá', 'para', 'tiene', 'ella', 'antes', 'estadas', 'sentidos', 'hubieses', 'estuvisteis', 'su', 'sí', 'mis', 'ellas', 'estoy', 'por', 'estados', 'quien', 'esa', 'sois', 'ha', 'la', 'habrán', 'estuviésemos', 'cual', 'estaba', 'hubieras', 'ti', 'estéis', 'tenías', 'cuando', 'o', 'estuviesen', 'ya', 'al', 'soy', 'algo', 'esos', 'entre', 'tienes', 'me', 'estará', 'hay', 'estaría', 'habías', 'muchos', 'era', 'esta', 'hubo', 'estaremos', 'tengas', 'estaréis', 'estuve', 'tenemos', 'estás', 'sería', 'tengan', 'tuya', 'fuisteis', 'de', 'estuvieron', 'fue', 'fuéramos', 'son', 'algunas', 'tendrían', 'había', 'esto', 'él', 'habéis', 'eras', 'seáis', 'tienen', 'seré', 'tendría', 'estaríamos', 'seremos', 'fuésemos', 'tuviste', 'seréis', 'hubieran', 'contra', 'estaríais', 'suyas', 'habrían', 'nosotros', 'os', 'tendré', 'estuviese', 'habréis', 'hayas', 'estuviera', 'tu', 'yo', 'tengáis', 'serás', 'tuviera', 'uno', 'tuyos', 'fueron', 'vuestros', 'haya', 'tuvieran', 'hubiéramos', 'seríais', 'fuimos', 'fuera', 'tuvierais', 'has', 'tendremos', 'otros', 'todos', 'tuyo', 'estuviste', 'tendréis', 'mío', 'nuestro', 'te', 'estaban', 'estabas', 'teníamos', 'míos', 'mía', 'eres', 'tenéis', 'tuvieron', 'nuestras', 'vosotros', 'ese', 'tuvimos', 'qué', 'e', 'estas', 'nos', 'está', 'más', 'vuestro', 'estábamos', 'sus', 'sentid', 'habidas', 'fueras', 'hayan', 'este', 'hubiese', 'estarías', 'tendríais', 'tenida', 'tenido', 'fuiste', 'le', 'todo', 'hubierais', 'fuese', 'sobre', 'mí', 'hubimos', 'fueses', 'ante', 'están', 'habremos', 'teníais', 'tendrás', 'éramos', 'fui', 'tuvisteis', 'hayáis', 'seríamos', 'sin', 'tuve', 'tendrán', 'estada', 'sintiendo', 'hubiera', 'fueseis', 'estamos', 'hubiesen', 'habidos', 'sentido', 'estad', 'hayamos', 'fuesen', 'habíais', 'suyo', 'mi', 'serían', 'unos', 'tengamos', 'las', 'tú', 'tuviéramos', 'no', 'seamos', 'sentida', 'estuvieses', 'estemos', 'sea', 'como', 'estar', 'nada', 'serías', 'poco', 'tuviésemos', 'han', 'vuestras', 'los', 'erais', 'hemos', 'lo', 'esas', 'se', 'vuestra', 'mucho', 'ni', 'siente']
# 313

# %% [markdown]
# La idea es remover los stop words es reducir la cantidad de Bag of Words y reducir información redundante.

# %% [markdown]
# # Ciclos con lista indexada
#
# En Python podemos incorporar un for dentro de una lista, este tipo de ciclos son más eficientes que la sintaxis inicial de los ciclos for.
#
#
# ```python
# ['valor' for 'valor' in 'lista' 'condicional: if valor cumple condición']
# ```

# %%
tokens_sin_stop=[]
for w in tokens:
  if w not in stop_words_nltk_en:
    tokens_sin_stop.append(w )
print( "Tokens: ", tokens_sin_stop )
print("Cantidad tokens:",len(tokens_sin_stop ))
print( "Bag of words: ", set(tokens_sin_stop)  )
print("Cantidad Bag of words: ",len(set(tokens_sin_stop) ))
# Out:
# Tokens:  ['communal', 'violence', 'bhainsa,', 'telangana.', '"stones', 'pelted', "muslims'", 'houses', 'houses', 'vehicles', 'set', 'ablaze…']
# Cantidad tokens: 12
# Bag of words:  {'ablaze…', '"stones', 'set', 'houses', 'communal', 'vehicles', 'pelted', 'violence', "muslims'", 'telangana.', 'bhainsa,'}
# Cantidad Bag of words:  11

# %%
tokens_sin_stop=[w for w in tokens if w not in stop_words_nltk_en] # eliminar los stop word
print( "Tokens: ", tokens_sin_stop )
print("Cantidad tokens:",len(tokens_sin_stop ))
print( "Bag of words: ", set(tokens_sin_stop)  )
print("Cantidad Bag of words: ",len(set(tokens_sin_stop) ))
# Out:
# Tokens:  ['communal', 'violence', 'bhainsa,', 'telangana.', '"stones', 'pelted', "muslims'", 'houses', 'houses', 'vehicles', 'set', 'ablaze…']
# Cantidad tokens: 12
# Bag of words:  {'ablaze…', '"stones', 'set', 'houses', 'communal', 'vehicles', 'pelted', 'violence', "muslims'", 'telangana.', 'bhainsa,'}
# Cantidad Bag of words:  11

# %% [markdown]
# # Stemming y Lemmatización
#
# Que sucede si utilizamos stemming y lematización.
#
#
# ¡Entendido! Permíteme explicarte teóricamente qué son el **stemming** y la **lematización**, y proporcionarte ejemplos en español.
#
# 1. **Stemming**:
#    - Su objetivo es reducir las palabras a su raíz o base, eliminando sufijos y prefijos.
#    - No considera el significado completo de la palabra, sino que se enfoca en la morfología.
#
# 2. **Lematización**:
#    - Busca encontrar el lema o forma base de una palabra.
#    - Utiliza análisis morfológico y contexto.
#
# - Ejemplos: Correr
#
#     - **Stemming:**
#       - **Word:** "running"
#       - **Stemmed form:** "run"
#     - **Lemmatization:**
#       - **Word:** "running"
#       - **Lemmatized form:** "run"
#     - **Stemming:**
#       - **Palabra:** "corriendo"
#       - **Forma stemmizada:** "corr"
#     - **Lematización:**
#       - **Palabra:** "correr"
#       - **Forma lematizada:** "correr"
#
# - Feliz
#
#     - **Stemming:**
#       - **Word:** "happier"
#       - **Stemmed form:** "happi"
#     - **Lemmatization:**
#       - **Word:** "happier"
#       - **Lemmatized form:** "happy"
#
#     - **Stemming:**
#       - **Palabra:** "felices"
#       - **Forma stemmizada:** "felic"
#     - **Lematización:**
#       - **Palabra:** "felices"
#       - **Forma lematizada:** "feliz"

# %%
porter = PorterStemmer() # Algotimo Stemming
tokens_stem = stem_strings1=[porter.stem(w) for w in tokens_sin_stop]
print("Stemming" )
print( "Tokens: ", tokens_stem )
print("Cantidad tokens:",len(tokens_stem ))
print( "Bag of words: ", set(tokens_stem)  )
print("Cantidad Bag of words: ",len(set(tokens_stem) ))
wordnet_lemmatizer = WordNetLemmatizer() # Algoritmo lemmatizar
tokens_lemma = [wordnet_lemmatizer.lemmatize(w) for w in tokens_sin_stop ]
print("Lematización")
print( "Tokens: ", tokens_lemma )
print("Cantidad tokens:",len(tokens_lemma ))
print( "Bag of words: ", set(tokens_lemma)  )
print("Cantidad Bag of words: ",len(set(tokens_lemma) ))
# Out:
# Stemming
# Tokens:  ['commun', 'violenc', 'bhainsa,', 'telangana.', '"stone', 'pelt', "muslims'", 'hous', 'hous', 'vehicl', 'set', 'ablaze…']
# Cantidad tokens: 12
# Bag of words:  {'ablaze…', 'pelt', 'violenc', 'commun', 'vehicl', 'set', 'hous', "muslims'", '"stone', 'telangana.', 'bhainsa,'}
# Cantidad Bag of words:  11
# Lematización
# Tokens:  ['communal', 'violence', 'bhainsa,', 'telangana.', '"stones', 'pelted', "muslims'", 'house', 'house', 'vehicle', 'set', 'ablaze…']
# Cantidad tokens: 12
# Bag of words:  {'ablaze…', 'house', 'vehicle', '"stones', 'set', 'communal', 'pelted', 'violence', "muslims'", 'telangana.', 'bhainsa,'}
# Cantidad Bag of words:  11

# %% [markdown]
# # Reto
#
# Realizar lematización y luego stemming.

# %% [markdown]
# # Documentos
#
# Ahora ¿qué pasa si realizamos este proceso con todos los documentos?
#
# Vamos a unir todos los documentos en un solo texto, donde un texto representará todos los tuits.
#
# Con .join() podemos unir una lista de textos, donde podemos especificar una separador especifico, en este caso el más práctico es un espacio.

# %%
texto_documentos = ' '.join(datos_x["text"]) # unir todos los textos, separados por espacio
texto_documentos = texto_documentos.lower()

# %%
texto_documentos
# Out:
# 'communal violence in bhainsa, telangana. "stones were pelted on muslims\' houses and some houses and vehicles were set ablaze… telangana: section 144 has been imposed in bhainsa from january 13 to 15, after clash erupted between two groups on january 12. po… arsonist sets cars ablaze at dealership https://t.co/goqvyjbpvi arsonist sets cars ablaze at dealership https://t.co/0gl7nucplb https://t.co/u1ccbhowh9 "lord jesus, your love brings freedom and pardon. fill me with your holy spirit and set my heart ablaze with your l… https://t.co/vltznnpni8 if this child was chinese, this tweet would have gone viral. social media would be ablaze. snl would have made a racist j… several houses have been set ablaze in ngemsibaa village, oku sub division in the north west region of cameroon by… https://t.co/99uhgazxy2 asansol: a bjp office in salanpur village was set ablaze last night. bjp has alleged that tmc is behind the incident. police has b… national security minister, kan dapaah\'s side chic has set the internet ablaze with her latest powerful video.… https://t.co/rhzomqvslj this creature who’s soul is no longer clarent but blue ablaze this thing carrying memories memories of… https://t.co/tbksndrdox images showing the havoc caused by the #cameroon military as they torched houses in #oku.the shameless military is reported… social media went bananas after chuba hubbard announced monday evening his plans to return to #okstate. https://t.co/pen… hausa youths set area office of apapa-iganmu local council development area ablaze. okada riders stormed the lg area office… under #mamatabanerjee political violence &amp; vandalism continues to unabated in west bengal! office in asanol was… amen! set the whole system ablaze, man. https://t.co/j08xhdcgbd images showing the havoc caused by the #cameroon military as they torched houses in #oku.the shameless military is… https://t.co/giwzch533d no cows today but our local factory is sadly still ablaze #redjanuary2020 https://t.co/cmyukzrckz rengoku sets my heart ablaze😔❤️🔥 p.s. i missed this style of coloring i do so here it is c: #鬼滅の刃 https://t.co/yruf9g68s0 paulzizkaphoto: “rundle ablaze” wishing you all a good evening... https://t.co/d0nlme1hqz https://t.co/hlvlt6qiip french cameroun set houses ablaze in ndu and roasted two young boys in their homes in #targeted killings in a #genocideinsou… cameroon\'s #bir soldiers on the 05/01/2020 invaded the #southerncameroons village of kimar - so setting ablaze a total of… as fires ablaze throughout the land/as the prophosized apocalypse comes to fruition/not a building standing/as we all come st… #thankfultuesday isaiah 43:2 when you pass through the waters, i will be with you; and when you pass through the r… https://t.co/jep3l1ou36 ⠀⠀when you walk through the fire, ⠀⠀you will not be scorched, and the ⠀⠀flames will not set you ablaze. ──── product… originally they were intended to be fired at boarders or the opposing ship\'s crew from gunners in the ships\'s riggi… https://t.co/z5vpwuybcl warm greetings to all on the occasion of #lohri. as winter passes by may everyone\'s woes and troubles be set ablaze in t… another arson in njikom,boyo,nwr. the ambazombies yesterday 13/1/2020 set ablaze the council building. which country in the wo… another public market in #haiti mysteriously set ablaze. the independent merchants, who are overwhelmingly women, become… that is kind true sadly i swear that jam will set the world ablaze marivan, kurdistan province monday, jan 13th, 2020 protesters set the propaganda banner of #qassemsoleimani ablaze. #i… marivan, kurdistan province monday, jan 13th, 2020 protesters set the propaganda banner of #qassemsoleimani ablaze… https://t.co/ivgcyjzlmk how can you turn a blind eye to the icident of setting ablaze more than 50 houses of h… https://t.co/ud84oqxg9k this love is so completely crazy. you\'ve been fucking with my dreams, ripped me like your torn up jeans. i don\'t ev… https://t.co/gcvyw5ezkb terms in a demon burning da ...

# %%
tokens = texto_documentos.split( ) # separa por espacios, \n, multiples espacios.
print( "Tokens: ", tokens[0:15] )
print("Cantidad tokens:",len(tokens ))
print("Cantidad Bag of words: ",len(set(tokens) ))
# Out:
# Tokens:  ['communal', 'violence', 'in', 'bhainsa,', 'telangana.', '"stones', 'were', 'pelted', 'on', "muslims'", 'houses', 'and', 'some', 'houses', 'and']
# Cantidad tokens: 195179
# Cantidad Bag of words:  40016

# %% [markdown]
# Ahora realizando una separación por espacio, se observa una gran cantidad de palabras, por esta razón es importante reducir la cantidad de Bag of words ya que no se puede analizar una cantidad tan alta de palabras.

# %%
tokens_sin_stop=[w for w in tokens if w not in stop_words_nltk_en]
print( "Tokens: ", tokens_sin_stop[0:15] )
print("Cantidad tokens:",len(tokens_sin_stop ))
print("Cantidad Bag of words: ",len(set(tokens_sin_stop) ))
# Out:
# Tokens:  ['communal', 'violence', 'bhainsa,', 'telangana.', '"stones', 'pelted', "muslims'", 'houses', 'houses', 'vehicles', 'set', 'ablaze…', 'telangana:', 'section', '144']
# Cantidad tokens: 124960
# Cantidad Bag of words:  39862

# %% [markdown]
# Pero utilizar una reducción por stop words no es suficiente, pues pasar de 40 mil a 39.862 palabras no es una reducción tan relevante.

# %%
porter = PorterStemmer() # Algotimo Stemming
tokens_stem = stem_strings1=[porter.stem(w) for w in tokens_sin_stop]
print("Stemming" )
# print( "Tokens: ", tokens_stem )
print("Cantidad tokens:",len(tokens_stem ))
# print( "Bag of words: ", set(tokens_stem)  )
print("Cantidad Bag of words: ",len(set(tokens_stem) ))
wordnet_lemmatizer = WordNetLemmatizer() # Algoritmo lemmatizar
tokens_lemma = [wordnet_lemmatizer.lemmatize(w) for w in tokens_sin_stop ]
print("Lematización")
# print( "Tokens: ", tokens_lemma )
print("Cantidad tokens:",len(tokens_lemma ))
# print( "Bag of words: ", set(tokens_lemma)  )
print("Cantidad Bag of words: ",len(set(tokens_lemma) ))
# Out:
# Stemming
# Cantidad tokens: 124960
# Cantidad Bag of words:  35714
# Lematización
# Cantidad tokens: 124960
# Cantidad Bag of words:  38360

# %% [markdown]
# Ahora, estos métodos con stemming y lematización.
#
# ¿Cómo podemos visualizar estos documentos?
#
# Un gráfico de barras podría ser, para ver la mayor frecuencia.

# %%
tokens_=nltk.FreqDist(  tokens )

fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 40016

# %% [markdown]
# El problema de estos gráficos es que no podemos graficar una cantidad tan grandes de palabras, pero también se observa que las palabras graficadas son stop word, son las palabras más frecuentes de los tuits

# %%
tokens_=nltk.FreqDist(  tokens_sin_stop )

fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 39862

# %% [markdown]
# Cuando eliminamos los stop words, podemos observar que existen muchas palabras que se repiten pero no tienen un significado claro.

# %%
tokens_=nltk.FreqDist(  tokens_stem )

fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW = 35714

# %%
tokens_=nltk.FreqDist(  tokens_lemma )

fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW = 38360

# %% [markdown]
# # Tokenización para tweet
#
# Existe una librería que se utiliza especificamente para tokenización en tweet, esta tienen en cuenta una estructura previa de los tuits.

# %%
tk= TweetTokenizer()
tokens_tweet = tk.tokenize( texto_documentos )
len(set(tokens_tweet))
# Out:
# 29315

# %%
tokens_=nltk.FreqDist(  tokens_tweet)

fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 29315

# %% [markdown]
# Este método para crear tokens realiza una reducción significativa con el bag of words, sin embargo, se puede realizar una reducción eliminando los stop words ya que estos son los que se repiten con mayor frecuencia.

# %%
tokens_tweet_no_stop=[w for w in tokens_tweet if w not in stop_words_nltk_en]
tokens_=nltk.FreqDist(  tokens_tweet_no_stop)

fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 29146

# %% [markdown]
# Aca observamos que en general con la mayoría de métodos para crear los tokens se presentan con mayor frecuencia los signos de puntiación. Para esto es necesario realizar un mejor procesamiento en el texto.
#
# ¿Cómo podemos hacer para eliminar los simbolos que no nos dan información?

# %%
print(re.sub(r'[^A-Za-z0-9]+',' ',texto)) # Elimina lo que no sea caracter o alfa númerico
print(re.sub(r'[^A-Za-z]+',' ',texto)) # Elimina lo que no sea caracter
print(re.sub(r"[^A-Za-z']+",' ',texto)) # Elimina lo que no sea caracter o alfa númerico, dejando '
# Out:
# communal violence in bhainsa telangana stones were pelted on muslims houses and some houses and vehicles were set ablaze
# communal violence in bhainsa telangana stones were pelted on muslims houses and some houses and vehicles were set ablaze
# communal violence in bhainsa telangana stones were pelted on muslims' houses and some houses and vehicles were set ablaze

# %%
texto_documentos_new= re.sub(r'[^A-Za-z]+',' ',texto_documentos)
tokens = texto_documentos_new.split( ) # separa por espacios, \n, multiples espacios.
tokens_sin_stop=[w for w in tokens if w not in stop_words_nltk_en]

# %%
tokens_=nltk.FreqDist(  tokens_sin_stop)

fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 27389

# %% [markdown]
# Se observa que el https es el que mas se repite, esto se debe a que la mayoría de tuits tienen una URL ¿Qué pasa si utilizamos la tokenización de tweet?
#
# ¿Cómo se puede quitar la URL del texto?

# %%
texto_documentos_new= re.sub(r"[^A-Za-z']+",' ',texto_documentos)
tokens = tk.tokenize( texto_documentos_new )
tokens_sin_stop=[w for w in tokens if w not in stop_words_nltk_en]
tokens_=nltk.FreqDist(  tokens_sin_stop)

fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 27688

# %%
texto_documentos_new= re.sub(r"[^A-Za-z']+",' ',texto_documentos)
texto_documentos_new= re.sub(r'https?://\S+|www\.\S+', ' ', texto_documentos_new)  # eliminar la URL
tokens = tk.tokenize( texto_documentos_new )
tokens_sin_stop=[w for w in tokens if w not in stop_words_nltk_en]
tokens_=nltk.FreqDist(  tokens_sin_stop)

fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 27688

# %% [markdown]
# ¿Cuál consideran que es la mejor tokenización?
#
# ¿Cuántos tokens hay por tuits?

# %%
texto_prueba = datos_x["text"].iloc[0]
texto_prueba=texto_prueba.lower() # TODO MINUSCULA
texto_documentos_new= re.sub(r"[^A-Za-z]+",' ',texto_prueba) # Eliminar simbolos
texto_documentos_new= re.sub(r'https?://\S+|www\.\S+', ' ', texto_documentos_new)  # eliminar la URL
tokens = tk.tokenize( texto_documentos_new ) # seperacion de tokens
tokens_sin_stop=[w for w in tokens if w not in stop_words_nltk_en] # eliminacción de stop word
len(tokens_sin_stop)
# Out:
# 12

# %%
len_tokens=[ ]
for texto_prueba in datos_x["text"].values:
    texto_prueba=texto_prueba.lower() # TODO MINUSCULA
    texto_documentos_new= re.sub(r"[^A-Za-z]+",' ',texto_prueba) # Eliminar simbolos
    texto_documentos_new= re.sub(r'https?://\S+|www\.\S+', ' ', texto_documentos_new)  # eliminar la URL
    tokens = tk.tokenize( texto_documentos_new ) # seperacion de tokens
    tokens_sin_stop=[w for w in tokens if w not in stop_words_nltk_en] # eliminacción de stop word
    len_tokens.append(len(tokens_sin_stop)) # Cantidad de tokens por tuit

# %%
datos_x["cantidad_tokens"]= len_tokens
datos_x["cantidad_tokens"].hist()
# Out:
# <Axes: >

# %%
datos_x["cantidad_tokens"].describe()
# Out:
# count    11370.000000
# mean        11.484169
# std          3.706580
# min          0.000000
# 25%          9.000000
# 50%         12.000000
# 75%         14.000000
# max         25.000000
# Name: cantidad_tokens, dtype: float64

# %%
(datos_x["cantidad_tokens"]==0).sum()
# Out:
# 2

# %%
datos_x["target"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 11365    0
# 11366    0
# 11367    0
# 11368    0
# 11369    1
# Name: target, Length: 11370, dtype: int64

# %%
texto_tweet=' '.join(datos_x.loc[ datos_x["target"]==1, "text"])
texto_tweet=texto_tweet.lower()
texto_tweet= re.sub(r'https?://\S+|www\.\S+', ' ', texto_tweet)  # eliminar la URL
texto_tweet= re.sub(r"[^A-Za-z]+",' ',texto_tweet) # Eliminar simbolos
tokens_tweet = tk.tokenize( texto_tweet ) # seperacion de tokens
tokens_tweet=[w for w in tokens_tweet if w not in stop_words_nltk_en] # eliminacción de stop word
tokens_=nltk.FreqDist(  tokens_tweet)
fdist = nltk.FreqDist(tokens_)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)

plt.figure(figsize=(20,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 5947

# %%
texto_tweet=" ".join(tokens_tweet)
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(texto_tweet)
 # mostrar nube de palabras
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
texto_tweet
# Out:
# 'Communal violence in Bhainsa Telangana Stones were pelted on Muslims houses and some houses and vehicles were set ablaze Telangana Section has been imposed in Bhainsa from January to after clash erupted between two groups on January Po Arsonist sets cars ablaze at dealership https t co gOQvyJbpVI Arsonist sets cars ablaze at dealership https t co gL NUCPlb https t co u CcBhOWh Lord Jesus your love brings freedom and pardon Fill me with your Holy Spirit and set my heart ablaze with your l https t co VlTznnPNi If this child was Chinese this tweet would have gone viral Social media would be ablaze SNL would have made a racist j Several houses have been set ablaze in Ngemsibaa village Oku sub division in the North West Region of Cameroon by https t co uHGAzxy Asansol A BJP office in Salanpur village was set ablaze last night BJP has alleged that TMC is behind the incident Police has b National Security Minister Kan Dapaah s side chic has set the internet ablaze with her latest powerful video https t co rhzOMQVSlj This creature who s soul is no longer clarent but blue ablaze This thing Carrying memories Memories of https t co tBKSNDrDoX Images showing the havoc caused by the Cameroon military as they torched houses in Oku The shameless military is reported Social media went bananas after Chuba Hubbard announced Monday evening his plans to return to okstate https t co peN Hausa youths set Area Office of Apapa Iganmu Local Council Development Area ablaze Okada Riders stormed the LG area office Under MamataBanerjee political violence amp vandalism continues to unabated in West Bengal office in Asanol was AMEN Set the whole system ablaze man https t co J xHDcGbD Images showing the havoc caused by the Cameroon military as they torched houses in Oku The shameless military is https t co gIwZCH D No cows today but our local factory is sadly still ablaze REDJanuary https t co CMyuKzrcKz Rengoku sets my heart ablaze P s I missed this style of coloring I do so here it is c https t co YrUF g s paulzizkaphoto Rundle Ablaze Wishing you all a good evening https t co d NlME HQz https t co hlVlT qiIp French cameroun set houses ablaze in Ndu and roasted two young boys in their homes in targeted killings in a GenocideInSou Cameroon s BIR soldiers on the invaded the SouthernCameroons Village of Kimar So setting ablaze a total of As fires ablaze throughout the land as the prophosized apocalypse comes to fruition not a building standing as we all come st ThankfulTuesday Isaiah When you pass through the waters I will be with you and when you pass through the r https t co jEp L oU When you walk through the fire you will not be scorched and the flames will not set you ablaze product Originally they were intended to be fired at boarders or the opposing ship s crew from gunners in the ships s riggi https t co z vPwuyBCL Warm greetings to all on the occasion of Lohri As winter passes by may everyone s woes and troubles be set ablaze in t Another arson in Njikom Boyo NWR The ambazombies yesterday set ablaze the Council building Which country in the wo Another public market in Haiti mysteriously set ablaze The independent merchants who are overwhelmingly women become that is kind true sadly I swear that jam will set the world ablaze Marivan Kurdistan Province Monday Jan th Protesters set the propaganda banner of QassemSoleimani ablaze I Marivan Kurdistan Province Monday Jan th Protesters set the propaganda banner of QassemSoleimani ablaze https t co IVGCYJZlmK How can you turn a blind eye to the icident of setting ablaze more than houses of H https t co UD oQxg K This love is so completely crazy You ve been fucking with my dreams ripped me like your torn up jeans I don t ev https t co GCVYW eZkb Terms in A Demon Burning Dark The Ruined People who cannot use magic or interact with it without some harm or ac https t co ZEDawOfuu Heartfelt appreciation to Prime Minister YAB Tun Dr wife YABhg Tun Dr Siti Hasmah Mohd Ali fo https t co YOwUp BYUP WATCH Former CM Akh ...
