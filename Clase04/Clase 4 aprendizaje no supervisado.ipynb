# %% [markdown]
# # Clase 4
#
# El objetivo de esta clase es desafiar a los estudiantes a aplicar lo aprendido en programación con Python para la manipulación y organización de datos, principalmente con la librería pandas. A lo largo de la clase, los estudiantes practicarán cómo usar Python para limpiar, transformar y preparar conjuntos de datos, adquiriendo habilidades prácticas en manipulación de datos que les serán útiles en futuros proyectos y análisis.
#
# * Lectura de datos.
# * Filtro de datos.
# * Transformación de datos.
# * Mas herramientas.
#
# Para esta clase se debe desarrollar un reto que tendrá una bonificación para los estudiantes que logren terminarlo.
#
# <center> <b> Reto </b> </center>
#
# Usando el dataset de "Customer Personality Analysis" [(Para conocer y descargar acerca de los datos de click aquí)](https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis), la empresa desea que usted analice los datos de la campaña de marketing. Por favor responda a los siguientes requerimientos.

# %%
# Importar librerías y establecer la conexión con google drive

# %% [markdown]
#   1. 	Se debe realizar la lectura de los datos, conocer el número de registros y adicionalmente se deben eliminar los registros que tengan datos faltantes, e informe cuantos registros se eliminaron.

# %%
# Punto 1

# %% [markdown]
#   2. Informe cuantos clientes aceptaron las campañas de promoción en cada una de las 6 campañas.

# %%
# Punto 2

# %% [markdown]
#   3.  Se necesita conocer cuantas promociones ha aceptado cada cliente, muestre los primeros 10 clientes.

# %%
# Punto 3

# %% [markdown]
# 4.	De los clientes que aceptaron en la última campaña (response), cuál es su edad promedio e ingreso promedio.

# %%
# Punto 4

# %% [markdown]
# 5.	Tanto para los consumidores que tienen hijos como los que no, calcule el gasto promedio sumando todas las categorías.

# %%
# Punto 5

# %% [markdown]
# 6.	Tanto para los consumidores que tienen hijos como los que no, calcule el gasto promedio para cada categoría. ¿Ha encontrado algún hallazgo interesante?

# %%
# Punto 6

# %% [markdown]
# 7.	Cuantos clientes aceptaron todas las promociones, 4 promociones, 3 promociones, 2 promociones, 1 promoción, ninguna de las promociones.

# %%
# Punto 7

# %% [markdown]
# ## Punto extra
#
# Se necesita clasificar a los consumidores en tres grupos de edad al momento de la recolección de los datos, teniendo en cuenta que los datos son del 2014. Los grupos de edad son los siguientes: grupo 1: 18-30 años, grupo2: 31-50 años y grupo 3: mayores de 50 años, además de eso, se quiere saber la cantidad de consumidores que hay en cada grupo.

# %% [markdown]
# 8.	¿Cuánto gastaron en promedio en cada categoría las personas de acuerdo con su estado civil?

# %%
# Punto 8

# %% [markdown]
# 9.	¿Cuánto gastaron en promedio en cada categoría las personas de acuerdo con su nivel de educación?

# %%
# Punto 9

# %% [markdown]
# 10.	¿podría decir que entre más ingresos tiene una persona más gasta en total? ¿O en una categoría en particular?

# %%
# Punto 10
