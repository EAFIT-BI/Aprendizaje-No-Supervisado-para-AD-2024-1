# %% [markdown]
# # Parcial
#
# Entrega: 12:00 pm 18 de marzo del 2024
#
# Se busca segmentar a los clientes con el fin de definir estrategias de marketing para tarjetas de crédito. Se dispone de datos sobre el uso de las tarjetas en los últimos 6 meses, y se pretende identificar diferentes segmentos de clientes para adaptar estrategias específicas a cada uno, con el objetivo de comprender mejor el perfil de los clientes [Fuente de datos](https://www.kaggle.com/datasets/arjunbhasin2013/ccdata).
#
# Para este caso solo se utilizaran las siguientes variables:
#
# * BALANCE : Balance amount left in their account to make purchases
#
# * PURCHASES : Amount of purchases made from account
#
# * CASHADVANCEFREQUENCY : How frequently the cash in advance being paid
#
# * CREDIT_LIMIT : Limit of Credit Card for user
#
# * PAYMENTS : Amount of Payment done by user
#
# * MINIMUM_PAYMENTS : Minimum amount of payments made by user
#
#
# Para este parcial se deben realizar los siguientes ítems:
#
#
# 1. Entendimiento de los datos: ¿los datos tienen registros faltantes? eliminelos si los tiene (2 puntos). Realice un análisis descriptivo de las variables (5 puntos).
#
# 2. Datos atípicos: Detectar posibles datos atípicos y considerar la opción de eliminarlos o no, justificando la decisión tomada. En caso de optar por la eliminación, aplicar la técnica pertinente enseñada en clase, manteniendo una proporción reducida de datos atípicos (5 puntos).
#
# 3. Realiza los 4 métodos de clúster para segmentar.
#
#   * K-means (3 puntos).
#   * K-medoids (3 puntos).
#   * DB-SCAN (3 puntos).
#   * Hierarchical clustering (3 puntos).
#
#   Por cada método debe encontrar el número de clústeres según los métodos enseñados (Para DB-SCAN se recomienda un epsilon entre  0.5 a 1).
#
#   Explique porque selecciono dicho número de clúster (o epsilon y minimo de puntos en el caso de DB-SCAN) (8 puntos)
#
# 4. Realice gráficos y/o tablas para visualizar los clústeres para todos los 4 métodos (5 puntos) ¿qué observa por cada clúster? (5 puntos).
#
# 5. Elaborar conclusiones generales basadas en los resultados obtenidos, identificando el algoritmo de clústering considerado como el mejor candidato y explicando las razones que respaldan dicha elección. (8 puntos).
