# %% [markdown]
# :😂🔥👨‍🚒🐕✈️💕🐶🐾🐈‍⬛✨🕊️💞❤️

# %%
# !pip install emoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.8/433.8 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import emoji

# %%
text= ['😂','🔥','👨‍🚒','🐕','✈️','💕','🐶','🐾','🐈‍⬛','✨','🕊️','💞','❤️']

# %%
emoji.demojize(text)
# Out:
# ':face_with_tears_of_joy::fire:👨\u200d🚒:dog:✈️:two_hearts::dog_face::paw_prints:🐈\u200d⬛:sparkles:🕊️:revolving_hearts:❤️'

# %%
emoji_text=[]

# %%
for emojis in text:
  emoji_text.append(emoji.demojize(emojis, delimiters=("","")))

# %%
emoji_text
# Out:
# ['face_with_tears_of_joy',
#  'fire',
#  'man_firefighter',
#  'dog',
#  'airplane',
#  'two_hearts',
#  'dog_face',
#  'paw_prints',
#  'black_cat',
#  'sparkles',
#  'dove',
#  'revolving_hearts',
#  'red_heart']
